# %% [markdown]
# <a href="https://colab.research.google.com/github/cataiap/Challanger-python/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# # **1. Análisis de facturación**

# %% [markdown]
# ## En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %% [markdown]
# ### A. Verificación de columnas y filas

# %%
#Verificación de columnas y filas
tienda.shape
tienda.tail(4)
# Out:
#            Producto Categoría del Producto    Precio  Costo de envío  \
# 2355      Impresora           Electrónicos  282800.0         15300.0
# 2356  Juego de mesa               Juguetes  122900.0          7200.0
# 2357       Cama box                Muebles  691300.0         35000.0
# 2358     Smartwatch           Electrónicos  195000.0          8600.0
#
#      Fecha de Compra       Vendedor Lugar de Compra  Calificación  \
# 2355      18/03/2023  Lucas Olivera          Bogotá             5
# 2356      06/07/2021  Lucas Olivera            Cali             5
# 2357      02/05/2022    Pedro Gomez           Pasto             1
# 2358      18/06/2022  Felipe Santos            Cali             4
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2355               Nequi                   1  4.60971 -74.08175
# 2356  Tarjeta de crédito                   4  3.43722 -76.52250
# 2357  Tarjeta de crédito                   2  1.21361 -77.28111
# ...

# %%
tienda2.shape
tienda2.tail(4)
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 2355  Lavadora de ropa      Electrodomésticos  1220100.0         65200.0
# 2356        Microondas      Electrodomésticos   797900.0         42900.0
# 2357         Iphone 15           Electrónicos  2224300.0        116600.0
# 2358         Bicicleta   Deportes y diversión   551000.0         27500.0
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2355      09/02/2020  Santiago Silva          Bogotá             4
# 2356      27/09/2022  Blanca Ramirez          Bogotá             5
# 2357      21/04/2022  Juan Fernandez        Medellín             5
# 2358      03/09/2022   Maria Alfonso        Medellín             4
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2355  Tarjeta de crédito                   5  4.60971 -74.08175
# 2356               Nequi                   1  4.60971 -74.08175
# 2357  Tarjeta de crédito                   2  6.25184 -75.56359
# ...

# %%
tienda3.shape
tienda3.tail(4)
# Out:
#                      Producto Categoría del Producto    Precio  \
# 2355  Dashboards con Power BI                 Libros   31800.0
# 2356         Silla de oficina                Muebles  477100.0
# 2357           Mesa de centro                Muebles  123100.0
# 2358      Modelado predictivo                 Libros   63400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 2355          2200.0      23/06/2022   Blanca Ramirez         Pereira
# 2356         25600.0      19/02/2023    Camila Rivera       Cartagena
# 2357          4700.0      19/09/2021   Blanca Ramirez          Bogotá
# 2358          9400.0      24/05/2022  Mariana Herrera        Medellín
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 2355             5  Tarjeta de crédito                   1   4.81333 -75.69611
# 2356             5  Tarjeta de crédito                   3  10.39972 -75.51444
# ...

# %%
tienda4.shape
tienda4.tail(4)
# Out:
#                 Producto   Categoría del Producto    Precio  Costo de envío  \
# 2354    Silla de oficina                  Muebles  342000.0         18600.0
# 2355        Vaso térmico     Deportes y diversión   36700.0          2400.0
# 2356        Set de ollas  Artículos para el hogar  151800.0          8300.0
# 2357  Cuerda para saltar     Deportes y diversión   11200.0          1300.0
#
#      Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 2354      17/05/2022   Felipe Santos     Bucaramanga             5
# 2355      03/05/2022   Camila Rivera          Bogotá             5
# 2356      15/06/2020  Blanca Ramirez            Cali             5
# 2357      17/11/2021   Felipe Santos          Bogotá             5
#
#           Método de pago  Cantidad de cuotas      lat       lon
# 2354  Tarjeta de crédito                   3  7.12539 -73.11980
# 2355  Tarjeta de crédito                   1  4.60971 -74.08175
# ...

# %% [markdown]
# ### B. Suma de valores Precio

# %% [markdown]
# #### Ingreso total tienda 1

# %%
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda1
# Out:
# np.float64(1150880400.0)

# %%
print(f"Ingreso total Tienda 1: {ingreso_tienda1:,.0f}")
# Out:
# Ingreso total Tienda 1: 1,150,880,400

# %% [markdown]
# #### Ingreso total tienda 2

# %%
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda2
# Out:
# np.float64(1116343500.0)

# %%
print(f"Ingreso total Tienda 2: {ingreso_tienda2:,.0f}")
# Out:
# Ingreso total Tienda 2: 1,116,343,500

# %% [markdown]
# #### Ingreso total tienda 3

# %%
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda3
# Out:
# np.float64(1098019600.0)

# %%
print(f"Ingreso total Tienda 3: {ingreso_tienda3:,.0f}")
# Out:
# Ingreso total Tienda 3: 1,098,019,600

# %% [markdown]
# #### Ingreso total tienda 4

# %%
ingreso_tienda4 = tienda4['Precio'].sum()
ingreso_tienda4
# Out:
# np.float64(1038375700.0)

# %%
print(f"Ingreso total Tienda 4: {ingreso_tienda4:,.0f}")
# Out:
# Ingreso total Tienda 4: 1,038,375,700

# %% [markdown]
# ### C. Resumen del ingreso total por tienda

# %%
resumen = pd.DataFrame({
    'tienda': ['Tienda 1','Tienda 2','Tienda 3','Tienda 4'],
    'ingreso_total_por_tienda': [ingreso_tienda1, ingreso_tienda2, ingreso_tienda3, ingreso_tienda4],
    'cantidad_de_filas': [tienda.shape[0], tienda2.shape[0], tienda3.shape[0], tienda4.shape[0]]
}).sort_values('ingreso_total_por_tienda', ascending=False)
resumen
# Out:
#      tienda  ingreso_total_por_tienda  cantidad_de_filas
# 0  Tienda 1              1.150880e+09               2359
# 1  Tienda 2              1.116344e+09               2359
# 2  Tienda 3              1.098020e+09               2359
# 3  Tienda 4              1.038376e+09               2358

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ## En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %% [markdown]
# ### A. Visualización de producto por categoría

# %% [markdown]
# #### Tienda 1

# %%
tienda['Categoría del Producto'].unique()
# Out:
# array(['Electrónicos', 'Muebles', 'Juguetes', 'Electrodomésticos',
#        'Artículos para el hogar', 'Deportes y diversión', 'Libros',
#        'Instrumentos musicales'], dtype=object)

# %% [markdown]
# #### Tienda 2

# %%
tienda2['Categoría del Producto'].unique()
# Out:
# array(['Muebles', 'Instrumentos musicales', 'Deportes y diversión',
#        'Electrónicos', 'Artículos para el hogar', 'Juguetes',
#        'Electrodomésticos', 'Libros'], dtype=object)

# %% [markdown]
# #### Tienda 3

# %%
tienda3['Categoría del Producto'].unique()
# Out:
# array(['Electrodomésticos', 'Muebles', 'Instrumentos musicales',
#        'Deportes y diversión', 'Electrónicos', 'Juguetes',
#        'Artículos para el hogar', 'Libros'], dtype=object)

# %% [markdown]
# #### Tienda 4

# %%
tienda4['Categoría del Producto'].unique()
# Out:
# array(['Electrodomésticos', 'Muebles', 'Deportes y diversión', 'Libros',
#        'Electrónicos', 'Instrumentos musicales', 'Juguetes',
#        'Artículos para el hogar'], dtype=object)

# %% [markdown]
# ### B. Contar ventas por categoría

# %% [markdown]
# #### Tienda 1

# %%
tienda['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda1_cat_prod = tienda.groupby('Categoría del Producto')[['Producto']].count().sort_values('Producto')
tienda1_cat_prod.plot(kind='barh', figsize=(8,6), color='red')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# #### Tienda 2

# %%
tienda2['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda2_cat_prod = tienda2.groupby('Categoría del Producto')[['Producto']].count().sort_values('Producto')
tienda2_cat_prod.plot(kind='barh', figsize=(8,6), color='blue')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# #### Tienda 3

# %%
tienda3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda3_cat_prod = tienda3.groupby('Categoría del Producto')[['Producto']].count().sort_values('Producto')
tienda3_cat_prod.plot(kind='barh', figsize=(8,6), color='green')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# #### Tienda 4

# %%
tienda4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
tienda4_cat_prod = tienda4.groupby('Categoría del Producto')[['Producto']].count().sort_values('Producto')
tienda4_cat_prod.plot(kind='barh', figsize=(8,6), color='purple')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ## En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %% [markdown]
# ### Tienda 1

# %%
tienda['Calificación'].head()
# Out:
# 0    4
# 1    1
# 2    1
# 3    4
# 4    5
# Name: Calificación, dtype: int64

# %%
tienda['Calificación'].isna().sum()
# Out:
# np.int64(0)

# %%
tienda['Calificación'].mean()
# Out:
# np.float64(3.976685036032217)

# %%
prom_calif_t1 = tienda['Calificación'].mean()
print(f"Calificación promedio Tienda 1: {prom_calif_t1:.2f}")
# Out:
# Calificación promedio Tienda 1: 3.98

# %%
tienda.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
#Calificación por categoría del producto
# Out:
# Categoría del Producto
# Juguetes                   4.077160
# Instrumentos musicales     4.049451
# Electrodomésticos          4.032051
# Electrónicos               4.004464
# Libros                     3.976879
# Muebles                    3.946237
# Deportes y diversión       3.897887
# Artículos para el hogar    3.748538
# Name: Calificación, dtype: float64

# %% [markdown]
# ### Tienda 2

# %%
tienda2['Calificación'].head()
# Out:
# 0    1
# 1    3
# 2    5
# 3    5
# 4    4
# Name: Calificación, dtype: int64

# %%
tienda2['Calificación'].isna().sum()
# Out:
# np.int64(0)

# %%
tienda2['Calificación'].mean()
# Out:
# np.float64(4.037303942348453)

# %%
prom_calif_t2 = tienda2['Calificación'].mean()
print(f"Calificación promedio Tienda 2: {prom_calif_t2:.2f}")
# Out:
# Calificación promedio Tienda 2: 4.04

# %%
tienda2.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
#Calificación por categoría del producto
# Out:
# Categoría del Producto
# Muebles                    4.092760
# Electrodomésticos          4.072131
# Artículos para el hogar    4.071823
# Deportes y diversión       4.065455
# Instrumentos musicales     4.035714
# Juguetes                   4.025559
# Electrónicos               3.971564
# Libros                     3.949239
# Name: Calificación, dtype: float64

# %% [markdown]
# ### Tienda 3

# %%
tienda3['Calificación'].head()
# Out:
# 0    4
# 1    3
# 2    5
# 3    4
# 4    1
# Name: Calificación, dtype: int64

# %%
tienda3['Calificación'].isna().sum()
# Out:
# np.int64(0)

# %%
tienda3['Calificación'].mean()
# Out:
# np.float64(4.048325561678677)

# %%
prom_calif_t3 = tienda3['Calificación'].mean()
print(f"Calificación promedio Tienda 3: {prom_calif_t3:.2f}")
# Out:
# Calificación promedio Tienda 3: 4.05

# %%
tienda3.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
#Calificación por categoría del producto
# Out:
# Categoría del Producto
# Juguetes                   4.196825
# Muebles                    4.098196
# Artículos para el hogar    4.073446
# Libros                     4.048649
# Electrodomésticos          4.010791
# Instrumentos musicales     4.005650
# Electrónicos               3.986696
# Deportes y diversión       3.938628
# Name: Calificación, dtype: float64

# %% [markdown]
# ### Tienda 4

# %%
tienda4['Calificación'].head()
# Out:
# 0    4
# 1    5
# 2    5
# 3    3
# 4    4
# Name: Calificación, dtype: int64

# %%
tienda4['Calificación'].isna().sum()
# Out:
# np.int64(0)

# %%
tienda4['Calificación'].mean()
# Out:
# np.float64(3.9957591178965224)

# %%
prom_calif_t4 = tienda4['Calificación'].mean()
print(f"Calificación promedio Tienda 4: {prom_calif_t4:.2f}")
# Out:
# Calificación promedio Tienda 4: 4.00

# %%
tienda4.groupby('Categoría del Producto')['Calificación'].mean().sort_values(ascending=False)
#Calificación por categoría del producto
# Out:
# Categoría del Producto
# Deportes y diversión       4.054152
# Libros                     4.042781
# Artículos para el hogar    4.009950
# Electrónicos               4.006652
# Muebles                    3.997917
# Juguetes                   3.988166
# Electrodomésticos          3.929134
# Instrumentos musicales     3.911765
# Name: Calificación, dtype: float64

# %% [markdown]
# ### Resumen

# %%
calificacion_promedio_tiendas = (pd.DataFrame({
    'tienda': ['Tienda 1','Tienda 2','Tienda 3','Tienda 4'],
    'calif_prom': [prom_calif_t1, prom_calif_t2, prom_calif_t3, prom_calif_t4]
})
.sort_values('calif_prom', ascending=False))

calificacion_promedio_tiendas
# Out:
#      tienda  calif_prom
# 2  Tienda 3    4.048326
# 1  Tienda 2    4.037304
# 3  Tienda 4    3.995759
# 0  Tienda 1    3.976685

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ## En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Tienda 1

# %%
conteo_prod_t1 = tienda['Producto'].value_counts()
conteo_prod_t1.head()
#contamos la cantidad de productos
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
conteo_prod_t1.head(10)
#Top 10 más vendidos
# Out:
# Producto
# Microondas                 60
# TV LED UHD 4K              60
# Armario                    60
# Secadora de ropa           58
# Mesa de noche              56
# Bloques de construcción    56
# Balón de baloncesto        55
# Bicicleta                  54
# Vaso térmico               54
# Refrigerador               54
# Name: count, dtype: int64

# %%
tienda['Producto'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', title='Top 10 productos más vendidos - Tienda 1', color='turquoise')
# Out:
# <Axes: title={'center': 'Top 10 productos más vendidos - Tienda 1'}, ylabel='Producto'>

# %%
conteo_prod_t1.sort_values(ascending=True).head(10)
#Top 10 menos vendidos
# Out:
# Producto
# Auriculares con micrófono      33
# Celular ABXY                   33
# Olla de presión                35
# Pandereta                      36
# Mochila                        39
# Ciencia de datos con Python    39
# Cuerda para saltar             40
# Asistente virtual              40
# Muñeca bebé                    40
# Dinosaurio Rex                 40
# Name: count, dtype: int64

# %%
tienda['Producto'].value_counts().tail(10).sort_values(ascending=False).plot(kind='barh', title='Top 10 productos menos vendidos - Tienda 1', color='maroon')
# Out:
# <Axes: title={'center': 'Top 10 productos menos vendidos - Tienda 1'}, ylabel='Producto'>

# %% [markdown]
# ### Tienda 2

# %%
conteo_prod_t2 = tienda2['Producto'].value_counts()
conteo_prod_t2.head()
#contamos la cantidad de productos
# Out:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64

# %%
conteo_prod_t2.head(10)
# top 10 más vendidos
# Out:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Secadora de ropa             57
# Iphone 15                    55
# Bloques de construcción      54
# Armario                      54
# Set de ollas                 52
# Name: count, dtype: int64

# %%
tienda2['Producto'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', title='Top 10 productos más vendidos - Tienda 2', color='turquoise')
# Out:
# <Axes: title={'center': 'Top 10 productos más vendidos - Tienda 2'}, ylabel='Producto'>

# %%
conteo_prod_t2.sort_values(ascending=True).head(10)
# Top 10 menos vendidos
# Out:
# Producto
# Juego de mesa        32
# Mesa de comedor      34
# Impresora            34
# Sillón               35
# Auriculares          37
# Asistente virtual    38
# Cubertería           39
# Smart TV             40
# Celular ABXY         41
# Estufa               42
# Name: count, dtype: int64

# %%
tienda2['Producto'].value_counts().tail(10).sort_values(ascending=False).plot(kind='barh', title='Top 10 productos menos vendidos - Tienda 2', color='maroon')
# Out:
# <Axes: title={'center': 'Top 10 productos menos vendidos - Tienda 2'}, ylabel='Producto'>

# %% [markdown]
# ### Tienda 3

# %%
conteo_prod_t3 = tienda3['Producto'].value_counts()
conteo_prod_t3.head()
#contamos la cantidad de productos
# Out:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64

# %%
conteo_prod_t3.head(10)
# Top 10 más vendidos
# Out:
# Producto
# Kit de bancas                57
# Mesa de comedor              56
# Cama king                    56
# Set de ollas                 55
# Mesa de noche                55
# Smart TV                     54
# Estufa                       53
# Cuerda para saltar           53
# Modelado predictivo          53
# Carrito de control remoto    52
# Name: count, dtype: int64

# %%
tienda3['Producto'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', title='Top 10 productos más vendidos - Tienda 3', color='turquoise')
# Out:
# <Axes: title={'center': 'Top 10 productos más vendidos - Tienda 3'}, ylabel='Producto'>

# %%
conteo_prod_t3.sort_values(ascending=True).head(10)
# Top 10 menos vendidos
# Out:
# Producto
# Bloques de construcción      35
# Microondas                   36
# Set de vasos                 36
# Mochila                      36
# Vaso térmico                 38
# Guitarra eléctrica           38
# Cubertería                   39
# Auriculares con micrófono    39
# Asistente virtual            39
# Muñeca bebé                  39
# Name: count, dtype: int64

# %%
tienda3['Producto'].value_counts().tail(10).sort_values(ascending=False).plot(kind='barh', title='Top 10 productos menos vendidos - Tienda 3', color='maroon')
# Out:
# <Axes: title={'center': 'Top 10 productos menos vendidos - Tienda 3'}, ylabel='Producto'>

# %% [markdown]
# ### Tienda 4

# %%
conteo_prod_t4 = tienda4['Producto'].value_counts()
conteo_prod_t4.head()
#contamos la cantidad de productos
# Out:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64

# %%
conteo_prod_t4.head(10)
# Top 10 productos más vendidos
# Out:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Mesa de comedor              55
# Mesa de noche                55
# Smart TV                     54
# Bloques de construcción      54
# Pandereta                    52
# Name: count, dtype: int64

# %%
tienda4['Producto'].value_counts().head(10).sort_values(ascending=True).plot(kind='barh', title='Top 10 productos más vendidos - Tienda 4', color='turquoise')
# Out:
# <Axes: title={'center': 'Top 10 productos más vendidos - Tienda 4'}, ylabel='Producto'>

# %%
conteo_prod_t4.sort_values(ascending=True).head(10)
# Out:
# Producto
# Guitarra eléctrica             33
# Armario                        34
# Guitarra acústica              37
# Ciencia de datos con Python    38
# Lavadora de ropa               38
# Refrigerador                   38
# Ajedrez de madera              39
# Smartwatch                     39
# Celular ABXY                   39
# Secadora de ropa               40
# Name: count, dtype: int64

# %%
tienda4['Producto'].value_counts().tail(10).sort_values(ascending=False).plot(kind='barh', title='Top 10 productos menos vendidos - Tienda 4', color='maroon')
# Out:
# <Axes: title={'center': 'Top 10 productos menos vendidos - Tienda 4'}, ylabel='Producto'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ## En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %% [markdown]
# ### Tienda 1

# %%
tienda['Costo de envío'].head()
# Out:
# 0     6900.0
# 1     8400.0
# 2    15900.0
# 3    41000.0
# 4    20200.0
# Name: Costo de envío, dtype: float64

# %%
tienda['Costo de envío'].mean()
# Out:
# np.float64(26018.60958033065)

# %%
prom_envio_t1 = tienda['Costo de envío'].mean()
print(f"Costo de envío promedio Tienda 1: {prom_envio_t1:.2f}")
# Out:
# Costo de envío promedio Tienda 1: 26018.61

# %% [markdown]
# ### Tienda 2

# %%
tienda2['Costo de envío'].head()
# Out:
# 0    15300.0
# 1     2300.0
# 2    23800.0
# 3    46400.0
# 4    19400.0
# Name: Costo de envío, dtype: float64

# %%
tienda2['Costo de envío'].mean()
# Out:
# np.float64(25216.235693090293)

# %%
prom_envio_t2 = tienda2['Costo de envío'].mean()
print(f"Costo de envío promedio Tienda 2: {prom_envio_t2:.2f}")
# Out:
# Costo de envío promedio Tienda 2: 25216.24

# %% [markdown]
# ### Tienda 3

# %%
tienda3['Costo de envío'].head()
# Out:
# 0    66600.0
# 1    13600.0
# 2    17400.0
# 3     3300.0
# 4    25900.0
# Name: Costo de envío, dtype: float64

# %%
tienda3['Costo de envío'].mean()
# Out:
# np.float64(24805.680373039424)

# %%
prom_envio_t3 = tienda3['Costo de envío'].mean()
print(f"Costo de envío promedio Tienda 3: {prom_envio_t3:.2f}")
# Out:
# Costo de envío promedio Tienda 3: 24805.68

# %% [markdown]
# ### Tienda 4

# %%
tienda4['Costo de envío'].head()
# Out:
# 0    56000.0
# 1    25400.0
# 2        0.0
# 3     1300.0
# 4     5600.0
# Name: Costo de envío, dtype: float64

# %%
tienda4['Costo de envío'].mean()
# Out:
# np.float64(23459.457167090754)

# %%
prom_envio_t4 = tienda4['Costo de envío'].mean()
print(f"Costo de envío promedio Tienda 4: {prom_envio_t4:.2f}")
# Out:
# Costo de envío promedio Tienda 4: 23459.46

# %% [markdown]
# ### Resumen

# %%
envio_promedio_tiendas = (pd.DataFrame({
    'tienda': ['Tienda 1','Tienda 2','Tienda 3','Tienda 4'],
    'envio_prom': [prom_envio_t1, prom_envio_t2, prom_envio_t3, prom_envio_t4]
})
.sort_values('envio_prom', ascending=False))

envio_promedio_tiendas
# Out:
#      tienda    envio_prom
# 0  Tienda 1  26018.609580
# 1  Tienda 2  25216.235693
# 2  Tienda 3  24805.680373
# 3  Tienda 4  23459.457167

# %% [markdown]
# # **Generando gráfico**

# %% [markdown]
# ## Ingresos por tienda

# %%
ingresos = pd.Series({
    'Tienda 1': ingreso_tienda1,
    'Tienda 2': ingreso_tienda2,
    'Tienda 3': ingreso_tienda3,
    'Tienda 4': ingreso_tienda4,
}).sort_values(ascending=True)

ingresos.plot(kind='barh', title='Ingreso total por tienda', xlabel='Ingresos', color='orange')
# Out:
# <Axes: title={'center': 'Ingreso total por tienda'}, xlabel='Ingresos'>

# %% [markdown]
# ## Categorías del produto

# %%
tienda['Categoría del Producto'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Categorías - Tienda 1', ylabel='')
# Out:
# <Axes: title={'center': 'Categorías - Tienda 1'}>

# %%
tienda2['Categoría del Producto'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Categorías - Tienda 2', ylabel='')
# Out:
# <Axes: title={'center': 'Categorías - Tienda 2'}>

# %%
tienda3['Categoría del Producto'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Categorías - Tienda 3', ylabel='')
# Out:
# <Axes: title={'center': 'Categorías - Tienda 3'}>

# %%
tienda4['Categoría del Producto'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Categorías - Tienda 4', ylabel='')
# Out:
# <Axes: title={'center': 'Categorías - Tienda 4'}>

# %% [markdown]
# ## Calificación por tienda

# %%
calificacion = pd.Series({
    'Tienda 1': prom_calif_t1,
    'Tienda 2': prom_calif_t2,
    'Tienda 3': prom_calif_t3,
    'Tienda 4': prom_calif_t4,
}).sort_values(ascending=False)

calificacion.plot(kind='bar', title='Calificación promedio por tienda', ylabel='Calificación', color='violet')
# Out:
# <Axes: title={'center': 'Calificación promedio por tienda'}, ylabel='Calificación'>

# %% [markdown]
# ## Envío promedio por tienda

# %%
envio = pd.Series({
    'Tienda 1': prom_envio_t1,
    'Tienda 2': prom_envio_t2,
    'Tienda 3': prom_envio_t3,
    'Tienda 4': prom_envio_t4,
}).sort_values(ascending=False)

envio.plot(kind='bar', title='Envío promedio por tienda', ylabel='Precio promedio', color='grey')
# Out:
# <Axes: title={'center': 'Envío promedio por tienda'}, ylabel='Precio promedio'>

# %% [markdown]
# # **Informe final**

# %% [markdown]
# ## **Introducción**
# Sr. Juan.
#
# En base al análisis de las 4 tiendas de Alura Store se utilizo Pandas para sumar ingresos, contar ventas por categoría y producto, promediar calificaciones y calcular el envío promedio. De esta forma logramor identificar cuál tienda conviene vender. Por lo que, a continuación, se sintetizan los resultados obtenidos.
#
# ## **Desarrollo**
# 1. Ingresos totales
#
# En este punto estimamos la facturación de cada tienda sumando la columna Precio. Dando como resultado lo siguiente:
#
# - Tienda 1: 1,150,880,400
#
# - Tienda 2: 1,116,343,500
#
# - Tienda 3: 1,098,019,600
#
# - Tienda 4: 1,038,375,700 (ingresos totales más bajo)
#
# 2. Ventas por categoría
#
# Aquí, se conto cuántos productos se venden por categoría en cada tienda para entender qué líneas tienen mejor venta dentro del negocio y cuáles son de baja venta:
#
# - Más vendidas (en las 4 tiendas): Muebles, Electrónicos y Juguetes.
#
# - Menos vendidas: Artículos para el hogar, Libros e Instrumentos musicales.
#
# 3. Calificación promedio de clientes
#
# Se calculo el promedio de Calificación por tienda para captar la satisfacción percibida por los clientes:
#
# - Tienda 3: 4,05
#
# - Tienda 2: 4,04
#
# - Tienda 4: 4,00
#
# - Tienda 1: 3,98
#
# 4. Productos más y menos vendidos
#
# Se indetifico los productos de mayor y menor venta para detectar cuales eran lideres de rotación y posibles candidatos a optimización del portafolio.
#
# Tienda 1:
# - Top en ventas: Microondas, TV LED UHD 4K, Armario, Secadora de ropa, Mesa de noche.
# - Top menos vendidos: Celular ABXY, Auriculares con micrófono, Olla de presión.
#
# Tienda 2:
# - Top en ventas: Iniciando en programación, Microondas, Batería, Pandereta.
# - Top menos vendidos: : Juego de mesa, Impresora, Mesa de comedor.
#
# Tienda 3
# - Top en ventas: Kit de bancas, Cama king, Mesa de comedor.
# - Top menos vendidos: : Bloques de construcción, Microondas, Mochila, Set de vasos.
#
# Tienda 4
# - Top en ventas: Cama box, Cubertería, Cama king.
# - Top menos vendidos: : Guitarra eléctrica, Armario, Guitarra acústica
#
#
# 5) Costo de envío promedio
#
# Se estimo el promedio de Costo de envío por tienda para entender el costo promedio de cada tienda:
#
# - Tienda 1: 26.018,61 (más alto)
#
# - Tienda 2: 25.216,24
#
# - Tienda 3: 24.805,68
#
# - Tienda 4: 23.459,46 (más bajo)
#
# ## **Conclusión**
#
# En síntesis, los datos confirman que la Tienda 4 es la candidata más razonable para vender: registra los ingresos más bajos y, aunque su calificación es aceptable, no supera a la Tienda 2 ni a la Tienda 3. Además, su envío más barato no se traduce en ventaja competitiva, pues ese costo lo asume el cliente. Con esta evidencia, no hay una justificación sólida para conservar la Tienda 4.
#
# Para potenciar lo que queda, conviene reforzar los productos que ya muestran mayor tracción en cada tienda: en Tienda 1, impulsar Microondas, TV LED UHD 4K, Armario, Secadora de ropa y Mesa de noche; en Tienda 2, priorizar Iniciando en programación, Microondas, Batería y Pandereta; en Tienda 3, apostar por Kit de bancas, Cama king y Mesa de comedor. Si por cualquier motivo decides no desprenderte de inmediato de la Tienda 4, concentra las acciones en Cama box, Cubertería y Cama king para acelerar rotación y mejorar su atractivo de venta.
#
# Dado que Tienda 1 lidera los ingresos pero presenta la calificación promedio más baja, el énfasis operativo debe estar en mejorar atención, posventa y experiencia (claridad de información, tiempos de respuesta y procesos de cambio/devolución). Con estas medidas, las tiendas restantes capitalizan sus fortalezas en Electrónica y Hogar y corrigen el principal punto débil, consolidando ingresos y percepción de servicio.

# %% [markdown]
# # **¡Extra! Análisis del desempeño geográfico**

# %% [markdown]
# ## Tienda 1

# %%
tienda[['lat','lon']].info()
tienda[['lat','lon']].isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     2359 non-null   float64
#  1   lon     2359 non-null   float64
# dtypes: float64(2)
# memory usage: 37.0 KB
# lat    0
# lon    0
# dtype: int64

# %%
tienda.plot(kind='scatter', x='lon', y='lat', s=40, alpha=0.3, title='Ubicación de ventas — Tienda 1')
plt.axis('equal'); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Tienda 2

# %%
tienda2[['lat','lon']].info()
tienda2[['lat','lon']].isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     2359 non-null   float64
#  1   lon     2359 non-null   float64
# dtypes: float64(2)
# memory usage: 37.0 KB
# lat    0
# lon    0
# dtype: int64

# %%
tienda2.plot(kind='scatter', x='lon', y='lat', s=40, alpha=0.3, title='Ubicación de ventas — Tienda 2')
plt.axis('equal'); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Tienda 3

# %%
tienda3[['lat','lon']].info()
tienda3[['lat','lon']].isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     2359 non-null   float64
#  1   lon     2359 non-null   float64
# dtypes: float64(2)
# memory usage: 37.0 KB
# lat    0
# lon    0
# dtype: int64

# %%
tienda3.plot(kind='scatter', x='lon', y='lat', s=40, alpha=0.3, title='Ubicación de ventas — Tienda 3')
plt.axis('equal'); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Tienda 4

# %%
tienda4[['lat','lon']].info()
tienda4[['lat','lon']].isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     2358 non-null   float64
#  1   lon     2358 non-null   float64
# dtypes: float64(2)
# memory usage: 37.0 KB
# lat    0
# lon    0
# dtype: int64

# %%
tienda4.plot(kind='scatter', x='lon', y='lat', s=40, alpha=0.3, title='Ubicación de ventas — Tienda 4')
plt.axis('equal'); plt.tight_layout(); plt.show()
